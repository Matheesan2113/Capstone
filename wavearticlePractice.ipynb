# %%
import pandas as pd

data = pd.read_csv('articles1.csv', error_bad_lines=False);
data_text = data[['content']]
data_text = data_text.reset_index()
documents = data_text

# %%
len(documents)
# Out:
# 50000

# %%
documents[:5]
# Out:
#    index                                            content
# 0      0  WASHINGTON  —   Congressional Republicans have...
# 1      1  After the bullet shells get counted, the blood...
# 2      2  When Walt Disney’s “Bambi” opened in 1942, cri...
# 3      3  Death may be the great equalizer, but it isn’t...
# 4      4  SEOUL, South Korea  —   North Korea’s leader, ...

# %% [markdown]
# ### Data Preprocessing

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
import warnings
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(2018)

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\mathe\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# #### Lemmatize example

# %%
print(WordNetLemmatizer().lemmatize('went', pos='v'))
# Out:
# go

# %% [markdown]
# #### Stemmer Example

# %%
stemmer = SnowballStemmer('english')
original_words = ['caresses', 'flies', 'dies', 'mules', 'denied','died', 'agreed', 'owned', 
           'humbled', 'sized','meeting', 'stating', 'siezing', 'itemization','sensational', 
           'traditional', 'reference', 'colonizer','plotted']
singles = [stemmer.stem(plural) for plural in original_words]
pd.DataFrame(data = {'original word': original_words, 'stemmed': singles})
# Out:
#    original word stemmed
# 0       caresses  caress
# 1          flies     fli
# 2           dies     die
# 3          mules    mule
# 4         denied    deni
# 5           died     die
# 6         agreed    agre
# 7          owned     own
# 8        humbled   humbl
# 9          sized    size
# 10       meeting    meet
# 11       stating   state
# 12       siezing    siez
# 13   itemization    item
# 14   sensational  sensat
# 15   traditional  tradit
# 16     reference   refer
# 17     colonizer   colon
# 18       plotted    plot

# %%
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))

def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
    return result

# %%
doc_sample = documents[documents['index'] == 2].values[0][1]

print('original document: ')
words = []
for word in doc_sample.split(' '):
    words.append(word)
print(words)
print('\n\n tokenized and lemmatized document: ')
print(preprocess(doc_sample))
# Out:
# original document:
# ['When', 'Walt', 'Disney’s', '“Bambi”', 'opened', 'in', '1942,', 'critics', 'praised', 'its', 'spare,', 'haunting', 'visual', 'style,', 'vastly', 'different', 'from', 'anything', 'Disney', 'had', 'done', 'before.', 'But', 'what', 'they', 'did', 'not', 'know', 'was', 'that', 'the', 'film’s', 'striking', 'appearance', 'had', 'been', 'created', 'by', 'a', 'Chinese', 'immigrant', 'artist,', 'who', 'took', 'as', 'his', 'inspiration', 'the', 'landscape', 'paintings', 'of', 'the', 'Song', 'dynasty.', 'The', 'extent', 'of', 'his', 'contribution', 'to', '“Bambi,”', 'which', 'remains', 'a', '', '', 'mark', 'for', 'film', 'animation,', 'would', 'not', 'be', 'widely', 'known', 'for', 'decades.', 'Like', 'the', 'film’s', 'title', 'character,', 'the', 'artist,', 'Tyrus', 'Wong,', 'weathered', 'irrevocable', 'separation', 'from', 'his', 'mother', '', '—', '', '', 'and,', 'in', 'the', 'hope', 'of', 'making', 'a', 'life', 'in', 'America,', 'incarceration,', 'isolation', 'and', 'rigorous', 'interrogation', '', '—', '', '', 'all', 'when', 'he', 'was', 'still', 'a', 'child.', 'In', 'the', 'years', 'that', 'followed,', 'he', 'endured', 'poverty,', 'discrimination', 'and', 'chronic', 'lack', 'of', 'recognition,', 'not', 'only', 'for', 'his', 'work', 'at', 'Disney', 'but', 'also', 'for', 'his', 'fine', 'art,', 'before', 'finding', 'acclaim', 'in', 'his', '90s.', 'Mr.', 'Wong', 'died', 'on', 'Friday', 'at', '106.', 'A', 'Hollywood', 'studio', 'artist,', 'painter,', 'printmaker,', 'calligrapher,', '', '', 'illustrator', 'and,', 'in', 'later', 'years,', 'maker', 'of', 'fantastical', 'kites,', 'he', 'was', 'one', 'of', 'the', 'most', 'celebrated', '', '', 'artists', 'of', 'the', '20th', 'century.', 'But', 'because', 'of', 'the', 'marginalization', 'to', 'which', '', '', 'were', 'long', 'subject,', 'he', 'passed', 'much', 'of', 'his', 'career', 'unknown', 'to', 'the', 'general', 'public.', 'Artistic', 'recognition,', 'when', 'Mr.', 'Wong', 'did', 'find', 'it,', 'was', 'all', 'the', 'more', 'noteworthy', 'for', 'the', 'fact', 'that', 'among', 'Chinese', 'immigrant', 'men', 'of', 'his', 'generation,', 'professional', 'prospects', 'were', 'largely', 'limited', 'to', 'menial', 'jobs', 'like', 'houseboy', 'and', 'laundryman.', 'Trained', 'as', 'a', 'painter,', 'Mr.', 'Wong', 'was', 'a', 'leading', 'figure', 'in', 'the', 'Modernist', 'movement', 'that', 'flourished', 'in', 'California', 'between', 'the', 'first', 'and', 'second', 'World', 'Wars.', 'In', '1932', 'and', 'again', 'in', '1934,', 'his', 'work', 'was', 'included', 'in', 'group', 'shows', 'at', 'the', 'Art', 'Institute', 'of', 'Chicago', 'that', 'also', 'featured', 'Picasso,', 'Matisse', 'and', 'Paul', 'Klee.', 'As', 'a', 'staff', 'artist', 'for', 'Hollywood', 'studios', 'from', 'the', '1930s', 'to', 'the', '1960s,', 'he', 'drew', 'storyboards', 'and', 'made', 'vibrant', 'paintings,', 'as', 'detailed', 'as', 'any', 'architectural', 'illustrations,', 'that', 'helped', 'the', 'director', 'envision', 'each', 'scene', 'before', 'it', 'was', 'shot.', 'Over', 'the', 'years', 'his', 'work', 'informed', 'the', 'look', 'of', 'animated', 'pictures', 'for', 'Disney', 'and', '', '', 'films', 'for', 'Warner', 'Brothers', 'and', 'other', 'studios,', 'among', 'them', '“The', 'Sands', 'of', 'Iwo', 'Jima”', '(1949)', '“Rebel', 'Without', 'a', 'Cause”', '(1955)', 'and', '“The', 'Wild', 'Bunch”', '(1969).', 'But', 'of', 'the', 'dozens', 'of', 'films', 'on', 'which', 'he', 'worked,', 'it', 'was', 'for', '“Bambi”', 'that', 'Mr.', 'Wong', 'was', '', '—', '', '', 'belatedly', '', '—', '', '', 'most', 'renowned.', '“He', 'was', 'truly', 'involved', 'with', 'every', 'phase', 'of', 'production,”', 'John', 'Canemaker,', 'an', '', '', 'animator', 'and', 'a', 'historian', 'of', 'animation', 'at', 'New', 'York', 'University,', 'said', 'in', 'an', 'interview', 'for', 'this', 'obituary', 'in', 'March.', '“He', 'created', 'an', 'art', 'direction', 'that', 'had', 'really', 'never', 'been', 'seen', 'before', 'in', 'animation.', '”', ' ...
#
#
#  tokenized and lemmatized document:
 'bring', 'relat', 'case', 'father', 'paper', 'son', 'pose', 'relat', 'attun', 'decept', 'unit', 'state', 'immigr', 'offici', 'chines', 'arriv', 'formid', 'inquisit', 'ensur', 'claim', 'question', 'come', 'like', 'gunfir', 'direct', 'villag', 'face', 'window', 'hous', 'hous', 'rice', 'wide', 'deep', 'tree', 'villag', 'lake', 'shop', 'sponsor', 'relat', 'interrog', 'separ', 'answer', 'match', 'arriv', 'major', 'mistak', 'seri', 'smaller', 'one', 'mean', 'deport', 'stand', 'chanc', 'pass', 'aspir', 'memor', 'rigor', 'dossier', 'know', 'coach', 'paper', 'ensu', 'interrog', 'hard', 'adult', 'undergo', 'month', 'wong', 'land', 'angel', 'island', 'immigr', 'station', 'elder', 'wong', 'travel', 'merchant', 'name', 'look', 'look', 'angel', 'island', 'consid', 'elli', 'island', 'west', 'coast', 'lisa', 'author', 'gold', 'mountain', 'nonfict', 'chronicl', 'famili', 'say', 'interview', 'continu', 'goal', 'differ', 'elli', 'island', 'suppos', 'welcom', 'angel', 'island', 'open', 'spe ...

# %%
processed_docs = documents['content'].map(preprocess)

# %%
processed_docs[:10]
# Out:
# 0    [washington, congression, republican, fear, co...
# 1    [bullet, shell, count, blood, dri, votiv, cand...
# 2    [walt, disney, bambi, open, critic, prais, spa...
# 3    [death, great, equal, necessarili, evenhand, f...
# 4    [seoul, south, korea, north, korea, leader, sa...
# 5    [london, queen, elizabeth, battl, cold, week, ...
# 6    [beij, presid, tsai, taiwan, sharpli, critic, ...
# 7    [danni, cahil, stand, slight, daze, blizzard, ...
# 8    [hillari, kerr, founder, digit, media, compani...
# 9    [angel, muñiz, famili, apart, bronx, paint, an...
# Name: content, dtype: object

# %% [markdown]
# ### Bag of words on the dataset

# %%
dictionary = gensim.corpora.Dictionary(processed_docs)

# %%
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break
# Out:
# 0 access
# 1 acknowledg
# 2 administr
# 3 advoc
# 4 afford
# 5 alli
# 6 american
# 7 anger
# 8 annual
# 9 anticip
# 10 appeal

# %%
dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
bow_corpus[2]
# Out:
# [(2, 1),
#  (4, 1),
#  (6, 3),
#  (13, 1),
#  (15, 1),
#  (25, 1),
#  (27, 1),
#  (28, 1),
#  (33, 1),
#  (36, 2),
#  (47, 1),
#  (51, 1),
#  (78, 1),
#  (82, 1),
#  (95, 1),
#  (97, 1),
#  (101, 1),
#  (103, 1),
#  (106, 3),
#  (107, 1),
#  (108, 3),
#  (112, 1),
#  (118, 1),
#  (120, 1),
#  (122, 1),
#  (125, 1),
#  (126, 1),
#  (127, 3),
#  (130, 1),
#  (132, 2),
#  (138, 1),
#  (139, 1),
#  (144, 3),
#  (149, 1),
#  (154, 2),
#  (158, 1),
#  (161, 1),
#  (164, 1),
#  (169, 1),
#  (183, 3),
#  (184, 2),
#  (189, 3),
#  (190, 1),
#  (204, 4),
#  (209, 1),
#  (212, 1),
#  (213, 7),
#  (218, 1),
#  (224, 2),
#  (226, 1),
#  (235, 6),
#  (241, 2),
#  (243, 1),
#  (248, 1),
#  (251, 1),
#  (263, 1),
#  (267, 2),
#  (268, 1),
#  (269, 2),
#  (274, 4),
#  (280, 1),
#  (281, 1),
#  (294, 1),
#  (297, 1),
#  (317, 2),
#  (320, 1),
#  (331, 1),
#  (337, 1),
#  (345, 2),
#  (351, 1),
#  (352, 10),
#  (359, 1),
#  (396, 2),
#  (402, 4),
#  (404, 1),
#  (406, 1),
#  (415, 2),
#  (419, 3),
#  (421, 1),
#  (427, 5),
#  (429, 1),
#  (432, 2),
#  (434, 3),
#  (442, 1),
#  (447, 1),
#  (448, 6),
#  (455, 1),
#  (465, 1),
#  (474, 1),
#  (481, 4),
#  (485, 1),
#  (490, 1),
#  (497, 1),
#  (507, 2),
#  (511, 1),
#  (514, 2),
#  (527, 1),
#  (531, 1),
#  (532, 1),
#  (549, 1),
#  (551, 2),
#  (560, 1),
#  (561, 1),
#  (572, 9),
#  (577, 5),
#  (580, 2),
#  (587, 1),
#  (589, 3),
#  (592, 7),
#  (597, 4),
#  (604, 1),
#  (607, 5),
#  (609, 1),
#  (612, 1),
#  (613, 1),
#  (614, 1),
#  (616, 4),
#  (618, 1),
#  (621, 1),
#  (622, 4),
#  (630, 3),
#  (631, 1),
#  (632, 6),
#  (633, 1),
#  (636, 2),
#  (637, 2),
#  (638, 1),
#  (643, 1),
#  (662, 4),
#  (664, 1),
#  (668, 2),
#  (670, 1),
#  (671, 1),
#  (678, 2),
#  (679, 1),
#  (680, 1),
#  (682, 2),
#  (688, 1),
#  (690, 3),
#  (698, 1),
#  (701, 9),
#  (702, 6),
#  (719, 1),
#  (736, 1),
#  (748, 1),
#  (752, 3),
#  (768, 2),
#  (772, 1),
#  (786, 1),
#  (797, 2),
#  (799, 1),
#  (828, 2),
#  (829, 4),
#  (830, 1),
#  (833, 2),
#  (834, 1),
#  (835, 3),
#  (842, 1),
#  (845, 1),
#  (849, 1),
#  (859, 2),
#  (860, 1),
#  (865, 1),
#  (868, 1),
#  (871, 1),
#  (879, 1),
#  (881, 1),
#  (886, 1),
#  (887, 1),
#  (896, 1),
#  (901, 8),
#  (903, 2),
#  (908, 1),
#  (930, 1),
#  (934, 1),
#  (943, 1),
#  (945, 2),
#  (970, 1),
#  (989, 1),
#  (991, 2),
#  (997, 16),
#  (1003, 1),
#  (1005, 1),
#  (1006, 3),
#  (1007, 1),
#  (1008, 1),
#  (1009, 1),
#  (1010, 1),
#  (1011, 1),
#  (1012, 1),
#  (1013, 1),
#  (1014, 1),
#  (1015, 3),
#  (1016, 2),
#  (1017, 1),
#  (1018, 1),
#  (1019, 9),
#  (1020, 1),
#  (1021, 10),
#  (1022, 1),
#  (1023, 1),
#  (1024, 1),
#  (1025, 1),
#  (1026, 17),
#  (1027, 2),
#  (1028, 1),
#  (1029, 1),
#  (1030, 1),
#  (1031, 1),
#  (1032, 1),
#  (1033, 1),
#  (1034, 1),
#  (1035, 1),
#  (1036, 4),
#  (1037, 1),
#  (1038, 1),
#  (1039, 2),
#  (1040, 2),
#  (1041, 1),
#  (1042, 1),
#  (1043, 1),
#  (1044, 1),
#  (1045, 1),
#  (1046, 1),
#  (1047, 3),
#  (1352, 1),
#  (1353, 1),
#  (1354, 1),
#  (1355, 3),
#  (1356, 1),
#  (1357, 2),
#  (1358, 1),
#  (1359, 2),
#  (1360, 1),
#  (1361, 1),
#  (1362, 1),
#  (1363, 1),
#  (1364, 1),
#  (1365, 2),
#  (1366, 2),
#  (1367, 1),
#  (1368, 2),
#  (1369, 1),
#  (1370, 1),
#  (1371, 2),
#  (1372, 4),
#  (1373, 2),
#  (1374, 1),
#  (1375, 1),
#  (1376, 1),
#  (1377, 1),
#  (1378, 1),
#  (1379, 1),
#  (1380, 1),
#  (1381, 1),
#  (1382, 1),
#  (1383, 1),
#  (1384, 3),
#  (1385, 1),
#  (1386, 1),
#  (1387, 3),
#  (1388, 1),
#  (1389, 3),
#  (1390, 3),
#  (1391, 1),
#  (1392, 1),
#  (1393, 1),
#  (1394, 1),
#  (1395, 2),
#  (1396, 1),
#  (1397, 38),
#  (1398, 1),
#  (1399, 2),
#  (1400, 1),
#  (1401, 1)]

# %%
bow_doc_2 = bow_corpus[2]

for i in range(len(bow_doc_2)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_2[i][0], 
                                                     dictionary[bow_doc_2[i][0]], 
                                                     bow_doc_2[i][1]))
# Out:
# Word 2 ("administr") appears 1 time.
# Word 4 ("afford") appears 1 time.
# Word 6 ("american") appears 3 time.
# Word 13 ("aspect") appears 1 time.
# Word 15 ("author") appears 1 time.
# Word 25 ("care") appears 1 time.
# Word 27 ("case") appears 1 time.
# Word 28 ("caus") appears 1 time.
# Word 33 ("choos") appears 1 time.
# Word 36 ("come") appears 2 time.
# Word 47 ("consid") appears 1 time.
# Word 51 ("continu") appears 1 time.
# Word 78 ("effect") appears 1 time.
# Word 82 ("entir") appears 1 time.
# Word 95 ("gain") appears 1 time.
# Word 97 ("general") appears 1 time.
# Word 101 ("hand") appears 1 time.
# Word 103 ("happen") appears 1 time.
# Word 106 ("hous") appears 3 time.
# Word 107 ("huge") appears 1 time.
# Word 108 ("illustr") appears 3 time.
# Word 112 ("inaugur") appears 1 time.
# Word 118 ("intern") appears 1 time.
# Word 120 ("involv") appears 1 time.
# Word 122 ("john") appears 1 time.
# Word 125 ("lack") appears 1 time.
# Word 126 ("late") appears 1 time.
# Word 127 ("later") appears 3 time.
# Word 130 ("lead") appears 1 time.
# Word 132 ("leav") appears 2 time.
# Word 138 ("lose") appears 1 time.
# Word 139 ("loss") appears 1 time.
# Word 144 ("month") appears 3 time.
# Word 149 ("offici") appears 1 time.
# Word 154 ("pass") appears 2 time.
# Word 158 ("perman") appears 1 time.
# Word 161 ("place") appears 1 time.
# Word 164 ("possibl") appears 1 time.
# Word 169 ("prepar") appears 1 time.
# Word 183 ("question") appears 3 time.
# Word 184 ("quick") appears 2 time.
# Word 189 ("relat") appears 3 time.
# Word 190 ("remain") appears 1 time.
# Word 204 ("seek") appears 4 time.
# Word 209 ("spend") appears 1 time.
# Word 212 ("stand") appears 1 time.
# Word 213 ("state") appears 7 time.
# Word 218 ("success") appears 1 time.
# Word 224 ("take") appears 2 time.
# Word 226 ("tell") appears 1 time.
# Word 235 ("unit") appears 6 time.
# Word 241 ("want") appears 2 time.
# Word 243 ("white") appears 1 time.
# Word 248 ("account") appears 1 time.
# Word 251 ("add") appears 1 time.
# Word 263 ("allow") appears 1 time.
# Word 267 ("answer") appears 2 time.
# Word 268 ("apart") appears 1 time.
# Word 269 ("appear") appears 2 time.
# Word 274 ("arriv") appears 4 time.
# Word 280 ("attack") appears 1 time.
# Word 281 ("attempt") appears 1 time.
# Word 294 ("beat") appears 1 time.
# Word 297 ("better") appears 1 time.
# Word 317 ("bring") appears 2 time.
# Word 320 ("build") appears 1 time.
# Word 331 ("call") appears 1 time.
# Word 337 ("card") appears 1 time.
# Word 345 ("chanc") appears 2 time.
# Word 351 ("children") appears 1 time.
# Word 352 ("chines") appears 10 time.
# Word 359 ("clear") appears 1 time.
# Word 396 ("countri") appears 2 time.
# Word 402 ("creat") appears 4 time.
# Word 404 ("credit") appears 1 time.
# Word 406 ("cri") appears 1 time.
# Word 415 ("daughter") appears 2 time.
# Word 419 ("death") appears 3 time.
# Word 421 ("declin") appears 1 time.
# Word 427 ("design") appears 5 time.
# Word 429 ("detail") appears 1 time.
# Word 432 ("differ") appears 2 time.
# Word 434 ("direct") appears 3 time.
# Word 442 ("document") appears 1 time.
# Word 447 ("dozen") appears 1 time.
# Word 448 ("draw") appears 6 time.
# Word 455 ("earlier") appears 1 time.
# Word 465 ("end") appears 1 time.
# Word 474 ("explain") appears 1 time.
# Word 481 ("famili") appears 4 time.
# Word 485 ("felt") appears 1 time.
# Word 490 ("fire") appears 1 time.
# Word 497 ("flourish") appears 1 time.
# Word 507 ("friend") appears 2 time.
# Word 511 ("generat") appears 1 time.
# Word 514 ("go") appears 2 time.
# Word 527 ("gunfir") appears 1 time.
# Word 531 ("half") appears 1 time.
# Word 532 ("hallmark") appears 1 time.
# Word 549 ("help") appears 1 time.
# Word 551 ("high") appears 2 time.
# Word 560 ("hold") appears 1 time.
# Word 561 ("home") appears 1 time.
# Word 572 ("immigr") appears 9 time.
# Word 577 ("includ") appears 5 time.
# Word 580 ("inform") appears 2 time.
# Word 587 ("inspector") appears 1 time.
# Word 589 ("interview") appears 3 time.
# Word 592 ("island") appears 7 time.
# Word 597 ("join") appears 4 time.
# Word 604 ("kill") appears 1 time.
# Word 607 ("know") appears 5 time.
# Word 609 ("land") appears 1 time.
# Word 612 ("larg") appears 1 time.
# Word 613 ("learn") appears 1 time.
# Word 614 ("level") appears 1 time.
# Word 616 ("life") appears 4 time.
# Word 618 ("linger") appears 1 time.
# Word 621 ("littl") appears 1 time.
# Word 622 ("live") appears 4 time.
# Word 630 ("long") appears 3 time.
# Word 631 ("longtim") appears 1 time.
# Word 632 ("look") appears 6 time.
# Word 633 ("lower") appears 1 time.
# Word 636 ("major") appears 2 time.
# Word 637 ("make") appears 2 time.
# Word 638 ("manhattan") appears 1 time.
# Word 643 ("mean") appears 1 time.
# Word 662 ("mother") appears 4 time.
# Word 664 ("move") appears 1 time.
# Word 668 ("name") appears 2 time.
# Word 670 ("near") appears 1 time.
# Word 671 ("need") appears 1 time.
# Word 678 ("newli") appears 2 time.
# Word 679 ("newspap") appears 1 time.
# Word 680 ("note") appears 1 time.
# Word 682 ("number") appears 2 time.
# Word 688 ("one") appears 1 time.
# Word 690 ("open") appears 3 time.
# Word 698 ("overlook") appears 1 time.
# Word 701 ("paint") appears 9 time.
# Word 702 ("paper") appears 6 time.
# Word 719 ("person") appears 1 time.
# Word 736 ("presid") appears 1 time.
# Word 748 ("properti") appears 1 time.
# Word 752 ("public") appears 3 time.
# Word 768 ("reason") appears 2 time.
# Word 772 ("record") appears 1 time.
# Word 786 ("resid") appears 1 time.
# Word 797 ("retir") appears 2 time.
# Word 799 ("return") appears 1 time.
# Word 828 ("scene") appears 2 time.
# Word 829 ("school") appears 4 time.
# Word 830 ("second") appears 1 time.
# Word 833 ("see") appears 2 time.
# Word 834 ("send") appears 1 time.
# Word 835 ("separ") appears 3 time.
# Word 842 ("shoot") appears 1 time.
# Word 845 ("show") appears 1 time.
# Word 849 ("similar") appears 1 time.
# Word 859 ("small") appears 2 time.
# Word 860 ("smaller") appears 1 time.
# Word 865 ("son") appears 1 time.
# Word 868 ("southern") appears 1 time.
# Word 871 ("special") appears 1 time.
# Word 879 ("staff") appears 1 time.
# Word 881 ("start") appears 1 time.
# Word 886 ("station") appears 1 time.
# Word 887 ("stay") appears 1 time.
# Word 896 ("street") appears 1 time.
# Word 901 ("studio") appears 8 time.
# Word 903 ("style") appears 2 time.
# Word 908 ("summer") appears 1 time.
# Word 930 ("terribl") appears 1 time.
# Word 934 ("think") appears 1 time.
# Word 943 ("today") appears 1 time.
# Word 945 ("tri") appears 2 time.
# Word 970 ("video") appears 1 time.
# Word 989 ("wife") appears 1 time.
# Word 991 ("window") appears 2 time.
# Word 997 ("work") appears 16 time.
# Word 1003 ("write") appears 1 time.
# Word 1005 ("york") appears 1 time.
# Word 1006 ("young") appears 3 time.
# Word 1007 ("abl") appears 1 time.
# Word 1008 ("acclaim") appears 1 time.
# Word 1009 ("adam") appears 1 time.
# Word 1010 ("adapt") appears 1 time.
# Word 1011 ("admiss") appears 1 time.
# Word 1012 ("adult") appears 1 time.
# Word 1013 ("affair") appears 1 time.
# Word 1014 ("affront") appears 1 time.
# Word 1015 ("afterward") appears 3 time.
# Word 1016 ("america") appears 2 time.
# Word 1017 ("amid") appears 1 time.
# Word 1018 ("andrew") appears 1 time.
# Word 1019 ("angel") appears 9 time.
# Word 1020 ("angri") appears 1 time.
# Word 1021 ("anim") appears 10 time.
# Word 1022 ("annett") appears 1 time.
# Word 1023 ("architectur") appears 1 time.
# Word 1024 ("arrang") appears 1 time.
# Word 1025 ("arthur") appears 1 time.
# Word 1026 ("artist") appears 17 time.
# Word 1027 ("asian") appears 2 time.
# Word 1028 ("aspir") appears 1 time.
# Word 1029 ("assum") appears 1 time.
# Word 1030 ("astonish") appears 1 time.
# Word 1031 ("atmospher") appears 1 time.
# Word 1032 ("attend") appears 1 time.
# Word 1033 ("attun") appears 1 time.
# Word 1034 ("austrian") appears 1 time.
# Word 1035 ("awar") appears 1 time.
# Word 1036 ("background") appears 4 time.
# Word 1037 ("bare") appears 1 time.
# Word 1038 ("baroqu") appears 1 time.
# Word 1039 ("bear") appears 2 time.
# Word 1040 ("begin") appears 2 time.
# Word 1041 ("belat") appears 1 time.
# Word 1042 ("benji") appears 1 time.
# Word 1043 ("bestow") appears 1 time.
# Word 1044 ("birth") appears 1 time.
# Word 1045 ("bitter") appears 1 time.
# Word 1046 ("blue") appears 1 time.
# Word 1047 ("book") appears 3 time.
# Word 1048 ("brood") appears 1 time.
# Word 1049 ("brothel") appears 1 time.
# Word 1050 ("brother") appears 3 time.
# Word 1051 ("brush") appears 2 time.
# Word 1052 ("bunch") appears 1 time.
# Word 1053 ("butcher") appears 1 time.
# Word 1054 ("butterfli") appears 1 time.
# Word 1055 ("button") appears 1 time.
# Word 1056 ("cafeteria") appears 1 time.
# Word 1057 ("calif") appears 1 time.
# Word 1058 ("california") appears 2 time.
# Word 1059 ("camouflag") appears 1 time.
# Word 1060 ("camp") appears 1 time.
# Word 1061 ("canva") appears 1 time.
# Word 1062 ("capit") appears 1 time.
# Word 1063 ("career") appears 1 time.
# Word 1064 ("celebr") appears 1 time.
# Word 1065 ("cent") appears 1 time.
# Word 1066 ("center") appears 1 time.
# Word 1067 ("centuri") appears 1 time.
# Word 1068 ("charact") appears 2 time.
# Word 1069 ("chester") appears 1 time.
# Word 1070 ("chicago") appears 1 time.
# Word 1071 ("child") appears 3 time.
# Word 1072 ("christma") appears 1 time.
# Word 1073 ("chronic") appears 1 time.
# Word 1074 ("chronicl") appears 1 time.
# Word 1075 ("circumv") appears 1 time.
# Word 1076 ("citizen") appears 2 time.
# Word 1077 ("claim") appears 1 time.
# Word 1078 ("climat") appears 1 time.
# Word 1079 ("coach") appears 1 time.
# Word 1080 ("coast") appears 1 time.
# Word 1081 ("collector") appears 1 time.
# Word 1082 ("colleg") appears 1 time.
# Word 1083 ("color") appears 3 time.
# Word 1084 ("compani") appears 2 time.
# Word 1085 ("confin") appears 1 time.
# Word 1086 ("confirm") appears 1 time.
# Word 1087 ("constrain") appears 1 time.
# Word 1088 ("contempl") appears 1 time.
# Word 1089 ("contribut") appears 2 time.
# Word 1090 ("crazi") appears 1 time.
# Word 1091 ("creation") appears 1 time.
# Word 1092 ("creatur") appears 1 time.
# Word 1093 ("critic") appears 1 time.
# Word 1094 ("curat") appears 1 time.
# Word 1095 ("curtail") appears 1 time.
# Word 1096 ("decad") appears 2 time.
# Word 1097 ("decemb") appears 1 time.
# Word 1098 ("decept") appears 1 time.
# Word 1099 ("deep") appears 1 time.
# Word 1100 ("deer") appears 1 time.
# Word 1101 ("dementia") appears 1 time.
# Word 1102 ("deport") appears 1 time.
# Word 1103 ("destroy") appears 1 time.
# Word 1104 ("detain") appears 1 time.
# Word 1105 ("die") appears 2 time.
# Word 1106 ("director") appears 1 time.
# Word 1107 ("discrimin") appears 1 time.
# Word 1108 ("disney") appears 15 time.
# Word 1109 ("dispers") appears 1 time.
# Word 1110 ("documentari") appears 1 time.
# Word 1111 ("dossier") appears 1 time.
# Word 1112 ("drastic") appears 1 time.
# Word 1113 ("dwarf") appears 1 time.
# Word 1114 ("dynasti") appears 2 time.
# Word 1115 ("earliest") appears 1 time.
# Word 1116 ("earn") appears 1 time.
# Word 1117 ("earthquak") appears 1 time.
# Word 1118 ("econom") appears 1 time.
# Word 1119 ("elder") appears 2 time.
# Word 1120 ("eleg") appears 1 time.
# Word 1121 ("elementari") appears 1 time.
# Word 1122 ("elli") appears 2 time.
# Word 1123 ("embark") appears 1 time.
# Word 1124 ("employe") appears 1 time.
# Word 1125 ("encourag") appears 3 time.
# Word 1126 ("endur") appears 2 time.
# Word 1127 ("enjoy") appears 1 time.
# Word 1128 ("ensu") appears 1 time.
# Word 1129 ("ensur") appears 1 time.
# Word 1130 ("enter") appears 1 time.
# Word 1131 ("entitl") appears 1 time.
# Word 1132 ("envis") appears 1 time.
# Word 1133 ("epithet") appears 1 time.
# Word 1134 ("error") appears 1 time.
# Word 1135 ("exclus") appears 1 time.
# Word 1136 ("exhibit") appears 3 time.
# Word 1137 ("exposur") appears 1 time.
# Word 1138 ("exquisit") appears 1 time.
# Word 1139 ("extent") appears 1 time.
# Word 1140 ("face") appears 1 time.
# Word 1141 ("fact") appears 2 time.
# Word 1142 ("fals") appears 1 time.
# Word 1143 ("fantast") appears 1 time.
# Word 1144 ("farm") appears 1 time.
# Word 1145 ("father") appears 12 time.
# Word 1146 ("fawn") appears 1 time.
# Word 1147 ("featur") appears 1 time.
# Word 1148 ("feet") appears 1 time.
# Word 1149 ("felix") appears 1 time.
# Word 1150 ("figur") appears 2 time.
# Word 1151 ("film") appears 7 time.
# Word 1152 ("filmmak") appears 1 time.
# Word 1153 ("find") appears 1 time.
# Word 1154 ("fine") appears 1 time.
# Word 1155 ("finish") appears 1 time.
# Word 1156 ("fledgl") appears 1 time.
# Word 1157 ("fling") appears 1 time.
# Word 1158 ("flock") appears 1 time.
# Word 1159 ("flower") appears 1 time.
# Word 1160 ("follow") appears 1 time.
# Word 1161 ("forest") appears 2 time.
# Word 1162 ("form") appears 1 time.
# Word 1163 ("formal") appears 1 time.
# Word 1164 ("formid") appears 1 time.
# Word 1165 ("forsak") appears 1 time.
# Word 1166 ("fortun") appears 1 time.
# Word 1167 ("found") appears 1 time.
# Word 1168 ("francisco") appears 4 time.
# Word 1169 ("fred") appears 1 time.
# Word 1170 ("friday") appears 1 time.
# Word 1171 ("gambl") appears 1 time.
# Word 1172 ("ghost") appears 1 time.
# Word 1173 ("goal") appears 1 time.
# Word 1174 ("gold") appears 1 time.
# Word 1175 ("good") appears 1 time.
# Word 1176 ("graduat") appears 1 time.
# Word 1177 ("grandchildren") appears 1 time.
# Word 1178 ("great") appears 1 time.
# Word 1179 ("group") appears 3 time.
# Word 1180 ("hadn") appears 1 time.
# Word 1181 ("harbor") appears 1 time.
# Word 1182 ("hard") appears 1 time.
# Word 1183 ("hat") appears 1 time.
# Word 1184 ("haunt") appears 1 time.
# Word 1185 ("have") appears 1 time.
# Word 1186 ("heritag") appears 1 time.
# Word 1187 ("historian") appears 1 time.
# Word 1188 ("hollywood") appears 3 time.
# Word 1189 ("honor") appears 1 time.
# Word 1190 ("hope") appears 2 time.
# Word 1191 ("hunter") appears 1 time.
# Word 1192 ("ident") appears 1 time.
# Word 1193 ("impass") appears 1 time.
# Word 1194 ("impos") appears 1 time.
# Word 1195 ("incarcer") appears 1 time.
# Word 1196 ("indefinit") appears 1 time.
# Word 1197 ("indiffer") appears 1 time.
# Word 1198 ("indign") appears 1 time.
# Word 1199 ("influenc") appears 3 time.
# Word 1200 ("inquir") appears 1 time.
# Word 1201 ("inquisit") appears 1 time.
# Word 1202 ("inspir") appears 4 time.
# Word 1203 ("institut") appears 3 time.
# Word 1204 ("intermedi") appears 1 time.
# Word 1205 ("interpret") appears 1 time.
# Word 1206 ("interrog") appears 4 time.
# Word 1207 ("invok") appears 1 time.
# Word 1208 ("irrevoc") appears 1 time.
# Word 1209 ("isol") appears 1 time.
# Word 1210 ("janitor") appears 1 time.
# Word 1211 ("japanes") appears 1 time.
# Word 1212 ("job") appears 1 time.
# Word 1213 ("juli") appears 1 time.
# Word 1214 ("junior") appears 2 time.
# Word 1215 ("keen") appears 1 time.
# Word 1216 ("kit") appears 1 time.
# Word 1217 ("lake") appears 1 time.
# Word 1218 ("landscap") appears 5 time.
# Word 1219 ("lapel") appears 1 time.
# Word 1220 ("law") appears 1 time.
# Word 1221 ("lay") appears 1 time.
# Word 1222 ("leaf") appears 1 time.
# Word 1223 ("legend") appears 1 time.
# Word 1224 ("lend") appears 2 time.
# Word 1225 ("lest") appears 1 time.
# Word 1226 ("librari") appears 1 time.
# Word 1227 ("limit") appears 1 time.
# Word 1228 ("line") appears 1 time.
# Word 1229 ("lisa") appears 1 time.
# Word 1230 ("lone") appears 1 time.
# Word 1231 ("loophol") appears 1 time.
# Word 1232 ("love") appears 2 time.
# Word 1233 ("lush") appears 1 time.
# Word 1234 ("lyric") appears 1 time.
# Word 1235 ("maintain") appears 1 time.
# Word 1236 ("maker") appears 1 time.
# Word 1237 ("march") appears 1 time.
# Word 1238 ("margin") appears 1 time.
# Word 1239 ("mark") appears 1 time.
# Word 1240 ("marri") appears 1 time.
# Word 1241 ("match") appears 1 time.
# Word 1242 ("member") appears 1 time.
# Word 1243 ("memor") appears 1 time.
# Word 1244 ("menial") appears 1 time.
# Word 1245 ("merchant") appears 1 time.
# Word 1246 ("mere") appears 1 time.
# Word 1247 ("meticul") appears 1 time.
# Word 1248 ("miser") appears 2 time.
# Word 1249 ("mistak") appears 1 time.
# Word 1250 ("misti") appears 1 time.
# Word 1251 ("modernist") appears 1 time.
# Word 1252 ("moodi") appears 1 time.
# Word 1253 ("mountain") appears 1 time.
# Word 1254 ("movement") appears 2 time.
# Word 1255 ("municip") appears 1 time.
# Word 1256 ("museum") appears 5 time.
# Word 1257 ("music") appears 1 time.
# Word 1258 ("mysteri") appears 1 time.
# Word 1259 ("narrat") appears 1 time.
# Word 1260 ("natur") appears 1 time.
# Word 1261 ("night") appears 1 time.
# Word 1262 ("nonfict") appears 1 time.
# Word 1263 ("noteworthi") appears 1 time.
# Word 1264 ("novel") appears 1 time.
# Word 1265 ("novelti") appears 1 time.
# Word 1266 ("obituari") appears 1 time.
# Word 1267 ("oblig") appears 1 time.
# Word 1268 ("occas") appears 1 time.
# Word 1269 ("organ") appears 1 time.
# Word 1270 ("orient") appears 2 time.
# Word 1271 ("ornat") appears 1 time.
# Word 1272 ("oti") appears 3 time.
# Word 1273 ("outdoor") appears 1 time.
# Word 1274 ("outstand") appears 1 time.
# Word 1275 ("owl") appears 1 time.
# Word 1276 ("painstak") appears 1 time.
# Word 1277 ("painter") appears 4 time.
# Word 1278 ("palett") appears 1 time.
# Word 1279 ("pamela") appears 1 time.
# Word 1280 ("pasadena") appears 1 time.
# Word 1281 ("pastel") appears 1 time.
# Word 1282 ("paul") appears 1 time.
# Word 1283 ("pearl") appears 1 time.
# Word 1284 ("petal") appears 1 time.
# Word 1285 ("phase") appears 1 time.
# Word 1286 ("picasso") appears 1 time.
# Word 1287 ("pictur") appears 1 time.
# Word 1288 ("pose") appears 2 time.
# Word 1289 ("poverti") appears 1 time.
# Word 1290 ("prais") appears 1 time.
# Word 1291 ("premier") appears 1 time.
# Word 1292 ("presenc") appears 1 time.
# Word 1293 ("previous") appears 2 time.
# Word 1294 ("proclaim") appears 1 time.
# Word 1295 ("product") appears 2 time.
# Word 1296 ("profession") appears 1 time.
# Word 1297 ("progress") appears 1 time.
# Word 1298 ("promot") appears 1 time.
# Word 1299 ("prospect") appears 2 time.
# Word 1300 ("provinc") appears 1 time.
# Word 1301 ("qualiti") appears 3 time.
# Word 1302 ("racial") appears 1 time.
# Word 1303 ("rank") appears 1 time.
# Word 1304 ("reach") appears 1 time.
# Word 1305 ("rebel") appears 1 time.
# Word 1306 ("recal") appears 3 time.
# Word 1307 ("recipi") appears 1 time.
# Word 1308 ("recognit") appears 3 time.
# Word 1309 ("render") appears 1 time.
# Word 1310 ("renown") appears 2 time.
# Word 1311 ("repetit") appears 1 time.
# Word 1312 ("repres") appears 1 time.
# Word 1313 ("repriev") appears 1 time.
# Word 1314 ("resent") appears 1 time.
# Word 1315 ("restrict") appears 1 time.
# Word 1316 ("retrospect") appears 3 time.
# Word 1317 ("rice") appears 1 time.
# Word 1318 ("rigor") appears 2 time.
# Word 1319 ("roman") appears 1 time.
# Word 1320 ("ruth") appears 2 time.
# Word 1321 ("sacramento") appears 2 time.
# Word 1322 ("sand") appears 1 time.
# Word 1323 ("sandwich") appears 1 time.
# Word 1324 ("scar") appears 1 time.
# Word 1325 ("sceneri") appears 1 time.
# Word 1326 ("scholarship") appears 2 time.
# Word 1327 ("schoolteach") appears 1 time.
# Word 1328 ("scrap") appears 1 time.
# Word 1329 ("sell") appears 1 time.
# Word 1330 ("sequenc") appears 1 time.
# Word 1331 ("seri") appears 2 time.
# Word 1332 ("seven") appears 1 time.
# Word 1333 ("sever") appears 1 time.
# Word 1334 ("shop") appears 2 time.
# Word 1335 ("sight") appears 1 time.
# Word 1336 ("sign") appears 2 time.
# Word 1337 ("silhouett") appears 1 time.
# Word 1338 ("simpl") appears 1 time.
# Word 1339 ("simultan") appears 1 time.
# Word 1340 ("sister") appears 1 time.
# Word 1341 ("sketch") appears 2 time.
# Word 1342 ("slowli") appears 1 time.
# Word 1343 ("snow") appears 1 time.
# Word 1344 ("song") appears 2 time.
# Word 1345 ("soon") appears 1 time.
# Word 1346 ("space") appears 1 time.
# Word 1347 ("spare") appears 2 time.
# Word 1348 ("specif") appears 1 time.
# Word 1349 ("spi") appears 1 time.
# Word 1350 ("split") appears 1 time.
# Word 1351 ("sponsor") appears 1 time.
# Word 1352 ("stark") appears 1 time.
# Word 1353 ("steadi") appears 1 time.
# Word 1354 ("streak") appears 1 time.
# Word 1355 ("strike") appears 3 time.
# Word 1356 ("stroke") appears 1 time.
# Word 1357 ("student") appears 2 time.
# Word 1358 ("studi") appears 1 time.
# Word 1359 ("subject") appears 2 time.
# Word 1360 ("subt") appears 1 time.
# Word 1361 ("suggest") appears 1 time.
# Word 1362 ("suppos") appears 1 time.
# Word 1363 ("survivor") appears 1 time.
# Word 1364 ("swallow") appears 1 time.
# Word 1365 ("talent") appears 2 time.
# Word 1366 ("teacher") appears 2 time.
# Word 1367 ("ten") appears 1 time.
# Word 1368 ("thousand") appears 2 time.
# Word 1369 ("titl") appears 1 time.
# Word 1370 ("trace") appears 1 time.
# Word 1371 ("train") appears 2 time.
# Word 1372 ("travel") appears 4 time.
# Word 1373 ("tree") appears 2 time.
# Word 1374 ("truli") appears 1 time.
# Word 1375 ("tuition") appears 1 time.
# Word 1376 ("undergo") appears 1 time.
# Word 1377 ("unforeseen") appears 1 time.
# Word 1378 ("univers") appears 1 time.
# Word 1379 ("unknown") appears 1 time.
# Word 1380 ("unmistak") appears 1 time.
# Word 1381 ("unoffici") appears 1 time.
# Word 1382 ("vast") appears 1 time.
# Word 1383 ("vibrant") appears 1 time.
# Word 1384 ("villag") appears 3 time.
# Word 1385 ("visual") appears 1 time.
# Word 1386 ("wake") appears 1 time.
# Word 1387 ("walt") appears 3 time.
# Word 1388 ("war") appears 1 time.
# Word 1389 ("warner") appears 3 time.
# Word 1390 ("water") appears 3 time.
# Word 1391 ("wear") appears 1 time.
# Word 1392 ("weather") appears 1 time.
# Word 1393 ("welcom") appears 1 time.
# Word 1394 ("west") appears 1 time.
# Word 1395 ("wide") appears 2 time.
# Word 1396 ("wild") appears 1 time.
# Word 1397 ("wong") appears 38 time.
# Word 1398 ("wood") appears 1 time.
# Word 1399 ("world") appears 2 time.
# Word 1400 ("writer") appears 1 time.
# Word 1401 ("youngest") appears 1 time.

# %% [markdown]
# ### TF-IDF

# %%
from gensim import corpora, models

tfidf = models.TfidfModel(bow_corpus)

# %%
corpus_tfidf = tfidf[bow_corpus]

# %%
from pprint import pprint

for doc in corpus_tfidf:
    pprint(doc)
    break
# Out:
# [(0, 0
# Words: 0.015*"polic" + 0.010*"offic" + 0.008*"report" + 0.006*"state" + 0.006*"shoot" + 0.005*"tell" + 0.005*"investig" + 0.004*"depart" + 0.004*"accord" + 0.004*"kill"
# Topic: 6
# Words: 0.014*"state" + 0.012*"court" + 0.005*"trump" + 0.005*"justic" + 0.005*"govern" + 0.005*"case" + 0.005*"presid" + 0.004*"north" + 0.004*"unit" + 0.004*"judg"
# Topic: 7
# Words: 0.032*"trump" + 0.009*"clinton" + 0.006*"republican" + 0.005*"state" + 0.005*"donald" + 0.005*"vote" + 0.005*"voter" + 0.005*"poll" + 0.005*"support" + 0.005*"campaign"
# Topic: 8
# Words: 0.005*"go" + 0.005*"know" + 0.005*"work" + 0.004*"think" + 0.004*"come" + 0.004*"tell" + 0.004*"game" + 0.003*"want" + 0.003*"play" + 0.003*"world"
# Topic: 9
# Words: 0.007*"student" + 0.006*"school" + 0.005*"attack" + 0.005*"north" + 0.004*"countri" + 0.004*"state" + 0.004*"nation" + 0.004*"korea" + 0.003*"tell" + 0.003*"polic"

# %% [markdown]
# Cool! Can you distinguish different topics using the words in each topic and their corresponding weights?

# %% [markdown]
# ### Running LDA using TF-IDF

# %%
lda_model_tfidf = gensim.models.ldamulticore.LdaMulticore(corpus_tfidf, num_topics=10, id2word=dictionary, passes=2, workers=5)

# %%
for idx, topic in lda_model_tfidf.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.007*"israel" + 0.004*"palestinian" + 0.004*"isra" + 0.003*"netanyahu" + 0.003*"trump" + 0.003*"jerusalem" + 0.002*"compani" + 0.002*"musk" + 0.002*"settlement" + 0.002*"resolut"
# Topic: 1 Word: 0.001*"market" + 0.001*"compani" + 0.001*"water" + 0.001*"china" + 0.001*"world" + 0.001*"health" + 0.001*"polic" + 0.001*"food" + 0.001*"citi" + 0.001*"work"
# Topic: 2 Word: 0.005*"turkey" + 0.005*"iran" + 0.004*"turkish" + 0.004*"erdogan" + 0.003*"iranian" + 0.002*"syria" + 0.002*"coup" + 0.002*"syrian" + 0.002*"trump" + 0.002*"istanbul"
# Topic: 3 Word: 0.005*"trump" + 0.004*"clinton" + 0.003*"poll" + 0.002*"vote" + 0.002*"voter" + 0.002*"percent" + 0.002*"republican" + 0.002*"black" + 0.002*"hillari" + 0.002*"democrat"
# Topic: 4 Word: 0.002*"clinton" + 0.002*"trump" + 0.002*"insur" + 0.002*"obamacar" + 0.001*"email" + 0.001*"film" + 0.001*"court" + 0.001*"health" + 0.001*"depart" + 0.001*"attorney"
# Topic: 5 Word: 0.009*"trump" + 0.005*"clinton" + 0.003*"republican" + 0.003*"campaign" + 0.003*"presid" + 0.003*"democrat" + 0.003*"obama" + 0.002*"senat" + 0.002*"cruz" + 0.002*"hillari"
# Topic: 6 Word: 0.007*"tesla" + 0.005*"uber" + 0.003*"compani" + 0.002*"vehicl" + 0.002*"marijuana" + 0.002*"car" + 0.002*"model" + 0.002*"musk" + 0.002*"espn" + 0.002*"drug"
# Topic: 7 Word: 0.007*"polic" + 0.004*"shoot" + 0.003*"attack" + 0.003*"offic" + 0.003*"appl" + 0.003*"kill" + 0.002*"suspect" + 0.002*"facebook" + 0.002*"breitbart" + 0.002*"milo"
# Topic: 8 Word: 0.004*"islam" + 0.004*"muslim" + 0.004*"isi" + 0.003*"immigr" + 0.002*"refuge" + 0.002*"attack" + 0.002*"trump" + 0.002*"migrant" + 0.002*"christian" + 0.002*"terrorist"
# Topic: 9 Word: 0.003*"pope" + 0.002*"cuban" + 0.002*"snapchat" + 0.002*"franci" + 0.002*"snap" + 0.002*"cuba" + 0.002*"trump" + 0.002*"castro" + 0.002*"compani" + 0.001*"schlafli"

# %% [markdown]
# ### Classification of the topics

# %% [markdown]
# ### Performance evaluation by classifying sample document using LDA Bag of Words model

# %%
processed_docs[2]
# Out:
# ['walt',
#  'disney',
#  'bambi',
#  'open',
#  'critic',
#  'prais',
#  'spare',
#  'haunt',
#  'visual',
#  'style',
#  'vast',
#  'differ',
#  'disney',
#  'know',
#  'film',
#  'strike',
#  'appear',
#  'creat',
#  'chines',
#  'immigr',
#  'artist',
#  'take',
#  'inspir',
#  'landscap',
#  'paint',
#  'song',
#  'dynasti',
#  'extent',
#  'contribut',
#  'bambi',
#  'remain',
#  'mark',
#  'film',
#  'anim',
#  'wide',
#  'know',
#  'decad',
#  'like',
#  'film',
#  'titl',
#  'charact',
#  'artist',
#  'tyrus',
#  'wong',
#  'weather',
#  'irrevoc',
#  'separ',
#  'mother',
#  'hope',
#  'make',
#  'life',
#  'america',
#  'incarcer',
#  'isol',
#  'rigor',
#  'interrog',
#  'child',
#  'year',
#  'follow',
#  'endur',
#  'poverti',
#  'discrimin',
#  'chronic',
#  'lack',
#  'recognit',
#  'work',
#  'disney',
#  'fine',
#  'find',
#  'acclaim',
#  'wong',
#  'die',
#  'friday',
#  'hollywood',
#  'studio',
#  'artist',
#  'painter',
#  'printmak',
#  'calligraph',
#  'illustr',
#  'later',
#  'year',
#  'maker',
#  'fantast',
#  'kit',
#  'celebr',
#  'artist',
#  'centuri',
#  'margin',
#  'long',
#  'subject',
#  'pass',
#  'career',
#  'unknown',
#  'general',
#  'public',
#  'artist',
#  'recognit',
#  'wong',
#  'noteworthi',
#  'fact',
#  'chines',
#  'immigr',
#  'generat',
#  'profession',
#  'prospect',
#  'larg',
#  'limit',
#  'menial',
#  'job',
#  'like',
#  'houseboy',
#  'laundryman',
#  'train',
#  'painter',
#  'wong',
#  'lead',
#  'figur',
#  'modernist',
#  'movement',
#  'flourish',
#  'california',
#  'second',
#  'world',
#  'war',
#  'work',
#  'includ',
#  'group',
#  'show',
#  'institut',
#  'chicago',
#  'featur',
#  'picasso',
#  'matiss',
#  'paul',
#  'klee',
#  'staff',
#  'artist',
#  'hollywood',
#  'studio',
#  'draw',
#  'storyboard',
#  'vibrant',
#  'paint',
#  'detail',
#  'architectur',
#  'illustr',
#  'help',
#  'director',
#  'envis',
#  'scene',
#  'shoot',
#  'year',
#  'work',
#  'inform',
#  'look',
#  'anim',
#  'pictur',
#  'disney',
#  'film',
#  'warner',
#  'brother',
#  'studio',
#  'sand',
#  'jima',
#  'rebel',
#  'caus',
#  'wild',
#  'bunch',
#  'dozen',
#  'film',
#  'work',
#  'bambi',
#  'wong',
#  'belat',
#  'renown',
#  'truli',
#  'involv',
#  'phase',
#  'product',
#  'john',
#  'canemak',
#  'anim',
#  'historian',
#  'anim',
#  'york',
#  'univers',
#  'say',
#  'interview',
#  'obituari',
#  'march',
#  'creat',
#  'direct',
#  'see',
#  'anim',
#  'wong',
#  'subject',
#  'water',
#  'paper',
#  'paint',
#  'major',
#  'retrospect',
#  'disney',
#  'famili',
#  'museum',
#  'francisco',
#  'museum',
#  'window',
#  'overlook',
#  'francisco',
#  'contempl',
#  'angel',
#  'island',
#  'decad',
#  'earlier',
#  'lone',
#  'seek',
#  'gain',
#  'admiss',
#  'countri',
#  'adam',
#  'want',
#  'wong',
#  'roman',
#  'wong',
#  'ga',
#  'bear',
#  'farm',
#  'villag',
#  'guangdong',
#  'provinc',
#  'young',
#  'child',
#  'exhibit',
#  'love',
#  'draw',
#  'encourag',
#  'father',
#  'seek',
#  'better',
#  'econom',
#  'prospect',
#  'father',
#  'embark',
#  'unit',
#  'state',
#  'leav',
#  'mother',
#  'sister',
#  'mother',
#  'oblig',
#  'travel',
#  'fals',
#  'ident',
#  'state',
#  'affair',
#  'know',
#  'chines',
#  'immigr',
#  'paper',
#  'hope',
#  'circumv',
#  'chines',
#  'exclus',
#  'sign',
#  'presid',
#  'chester',
#  'arthur',
#  'drastic',
#  'curtail',
#  'number',
#  'chines',
#  'peopl',
#  'allow',
#  'enter',
#  'countri',
#  'earliest',
#  'unit',
#  'state',
#  'law',
#  'impos',
#  'sever',
#  'restrict',
#  'immigr',
#  'unforeseen',
#  'loophol',
#  'open',
#  'form',
#  'francisco',
#  'earthquak',
#  'huge',
#  'number',
#  'municip',
#  'document',
#  'includ',
#  'birth',
#  'immigr',
#  'record',
#  'destroy',
#  'newli',
#  'arriv',
#  'chines',
#  'capit',
#  'loss',
#  'maintain',
#  'bear',
#  'francisco',
#  'unit',
#  'state',
#  'citizen',
#  'entitl',
#  'bring',
#  'relat',
#  'case',
#  'father',
#  'paper',
#  'son',
#  'pose',
#  'relat',
#  'attun',
#  'decept',
#  'unit',
#  'state',
#  'immigr',
#  'offici',
#  'chines',
#  'arriv',
#  'formid',
#  'inquisit',
#  'ensur',
#  'claim',
#  'question',
#  'come',
#  'like',
#  'gunfir',
#  'direct',
#  'villag',
#  'face',
#  'window',
#  'hous',
#  'hous',
#  'rice',
#  'wide',
#  'deep',
#  'tree',
#  'villag',
#  'lake',
#  'shop',
#  'sponsor',
#  'relat',
#  'interrog',
#  'separ',
#  'answer',
#  'match',
#  'arriv',
#  'major',
#  'mistak',
#  'seri',
#  'smaller',
#  'one',
#  'mean',
#  'deport',
#  'stand',
#  'chanc',
#  'pass',
#  'aspir',
#  'memor',
#  'rigor',
#  'dossier',
#  'know',
#  'coach',
#  'paper',
#  'ensu',
#  'interrog',
#  'hard',
#  'adult',
#  'undergo',
#  'month',
#  'wong',
#  'land',
#  'angel',
#  'island',
#  'immigr',
#  'station',
#  'elder',
#  'wong',
#  'travel',
#  'merchant',
#  'name',
#  'look',
#  'look',
#  'angel',
#  'island',
#  'consid',
#  'elli',
#  'island',
#  'west',
#  'coast',
#  'lisa',
#  'author',
#  'gold',
#  'mountain',
#  'nonfict',
#  'chronicl',
#  'famili',
#  'say',
#  'interview',
#  'continu',
#  'goal',
#  'differ',
#  'elli',
#  'island',
#  'suppos',
#  'welcom',
#  'angel',
#  'island',
#  'open',
#  'specif',
#  'chines',
#  'wong',
#  'father',
#  'previous',
#  'live',
#  'unit',
#  'state',
#  'look',
#  'abl',
#  'clear',
#  'immigr',
#  'quick',
#  'arriv',
#  'detain',
#  'island',
#  'near',
#  'month',
#  'child',
#  'immigr',
#  'hold',
#  'scar',
#  'half',
#  'death',
#  'cri',
#  'wong',
#  'recal',
#  'tyrus',
#  'documentari',
#  'direct',
#  'pamela',
#  'premier',
#  'miser',
#  'miser',
#  'hat',
#  'place',
#  'presenc',
#  'interpret',
#  'stenograph',
#  'young',
#  'pose',
#  'look',
#  'interrog',
#  'inspector',
#  'father',
#  'question',
#  'prepar',
#  'answer',
#  'error',
#  'sacramento',
#  'join',
#  'father',
#  'schoolteach',
#  'american',
#  'tyrus',
#  'know',
#  'tyrus',
#  'wong',
#  'soon',
#  'afterward',
#  'father',
#  'separ',
#  'elder',
#  'wong',
#  'move',
#  'angel',
#  'seek',
#  'work',
#  'reason',
#  'lose',
#  'time',
#  'tyrus',
#  'live',
#  'sacramento',
#  'boardinghous',
#  'attend',
#  'elementari',
#  'school',
#  'year',
#  'later',
#  'possibl',
#  'tyrus',
#  'travel',
#  'angel',
#  'join',
#  'father',
#  'work',
#  'gambl',
#  'live',
#  'boardinghous',
#  'sandwich',
#  'butcher',
#  'shop',
#  'brothel',
#  'school',
#  'tyrus',
#  'work',
#  'houseboy',
#  'pasadena',
#  'famili',
#  'earn',
#  'cent',
#  'teacher',
#  'father',
#  'train',
#  'night',
#  'calligraphi',
#  'have',
#  'brush',
#  'water',
#  'trace',
#  'ghost',
#  'charact',
#  'newspap',
#  'afford',
#  'draw',
#  'paper',
#  'tyrus',
#  'junior',
#  'high',
#  'teacher',
#  'note',
#  'draw',
#  'talent',
#  'arrang',
#  'summer',
#  'scholarship',
#  'oti',
#  'institut',
#  'angel',
#  'account',
#  'indiffer',
#  'student',
#  'public',
#  'school',
#  'tyrus',
#  'call',
#  'institut',
#  'oti',
#  'colleg',
#  'design',
#  'scholarship',
#  'end',
#  'declin',
#  'return',
#  'junior',
#  'high',
#  'father',
#  'scrap',
#  'tuition',
#  'small',
#  'fortun',
#  'stay',
#  'oti',
#  'youngest',
#  'student',
#  'studi',
#  'year',
#  'simultan',
#  'work',
#  'school',
#  'janitor',
#  'graduat',
#  'long',
#  'afterward',
#  'father',
#  'die',
#  'leav',
#  'young',
#  'wong',
#  'entir',
#  'wong',
#  'artist',
#  'work',
#  'progress',
#  'administr',
#  'creat',
#  'paint',
#  'librari',
#  'public',
#  'space',
#  'friend',
#  'includ',
#  'artist',
#  'benji',
#  'okubo',
#  'found',
#  'orient',
#  'artist',
#  'group',
#  'angel',
#  'organ',
#  'exhibit',
#  'member',
#  'work',
#  'level',
#  'exposur',
#  'asian',
#  'artist',
#  'time',
#  'wong',
#  'newli',
#  'marri',
#  'need',
#  'steadi',
#  'work',
#  'join',
#  'disney',
#  'creat',
#  'thousand',
#  'intermedi',
#  'draw',
#  'bring',
#  'anim',
#  'sequenc',
#  'life',
#  'asian',
#  'novelti',
#  'hollywood',
#  'studio',
#  'wong',
#  'keen',
#  'awar',
#  'fact',
#  'disney',
#  'later',
#  'warner',
#  'brother',
#  'fling',
#  'racial',
#  'epithet',
#  'assum',
#  'sight',
#  'work',
#  'compani',
#  'cafeteria',
#  'affront',
#  'painstak',
#  'repetit',
#  'wong',
#  'quick',
#  'work',
#  'anim',
#  'terribl',
#  'talent',
#  'landscap',
#  'artist',
#  'painter',
#  'canemak',
#  'say',
#  'repriev',
#  'come',
#  'late',
#  'wong',
#  'learn',
#  'disney',
#  'adapt',
#  'bambi',
#  'life',
#  'wood',
#  'novel',
#  'austrian',
#  'writer',
#  'felix',
#  'salten',
#  'fawn',
#  'mother',
#  'kill',
#  'hunter',
#  'tri',
#  'anim',
#  'book',
#  'disney',
#  'reach',
#  'impass',
#  'studio',
#  'enjoy',
#  'great',
#  'success',
#  'anim',
#  'film',
#  'snow',
#  'white',
#  'seven',
#  'dwarf',
#  'baroqu',
#  'product',
#  'background',
#  'petal',
#  'flower',
#  'leaf',
#  'tree',
#  'meticul',
#  'repres',
#  'attempt',
#  'similar',
#  'style',
#  'bambi',
#  'ornat',
#  'background',
#  'camouflag',
#  'deer',
#  'forest',
#  'creatur',
#  'narrat',
#  'center',
#  'wong',
#  'spi',
#  'chanc',
#  'say',
#  'outdoor',
#  'sceneri',
#  'recal',
#  'video',
#  'interview',
#  'year',
#  'afterward',
#  'add',
#  'say',
#  'landscap',
#  'painter',
#  'invok',
#  'exquisit',
#  'landscap',
#  'paint',
#  'song',
#  'dynasti',
#  'render',
#  'watercolor',
#  'pastel',
#  'seri',
#  'natur',
#  'scene',
#  'moodi',
#  'lyric',
#  'atmospher',
#  'lush',
#  'spare',
#  'background',
#  'subt',
#  'suggest',
#  'stroke',
#  'brush',
#  'walt',
#  'disney',
#  'go',
#  'crazi',
#  'say',
#  'canemak',
#  'write',
#  'wong',
#  'book',
#  'anim',
#  'begin',
#  'live',
#  'disney',
#  'inspir',
#  'sketch',
#  'artist',
#  'say',
#  'love',
#  'indefinit',
#  'qualiti',
#  'mysteri',
#  'qualiti',
#  'forest',
#  'wong',
#  'unoffici',
#  'promot',
#  'rank',
#  'inspir',
#  'sketch',
#  'artist',
#  'canemak',
#  'explain',
#  'design',
#  'person',
#  'go',
#  'question',
#  'color',
#  'influenc',
#  'music',
#  'special',
#  'effect',
#  'look',
#  'draw',
#  'inspir',
#  'peopl',
#  'wong',
#  'spend',
#  'year',
#  'paint',
#  'illustr',
#  'inform',
#  'aspect',
#  'bambi',
#  'finish',
#  'film',
#  'lend',
#  'brood',
#  'qualiti',
#  'stark',
#  'landscap',
#  'misti',
#  'desatur',
#  'palett',
#  'figur',
#  'see',
#  'silhouett',
#  'influenc',
#  'unmistak',
#  'wake',
#  'bitter',
#  'employe',
#  'strike',
#  'year',
#  'disney',
#  'fire',
#  'wong',
#  'choos',
#  'strike',
#  'felt',
#  'studio',
#  'good',
#  'canemak',
#  'say',
#  'amid',
#  'linger',
#  'climat',
#  'resent',
#  'bambi',
#  'wong',
#  'appear',
#  'credit',
#  'mere',
#  'background',
#  'artist',
#  'wong',
#  'join',
#  'warner',
#  'brother',
#  'work',
#  'lend',
#  'occas',
#  'studio',
#  'retir',
#  'indign',
#  'endur',
#  'confin',
#  'studio',
#  'tri',
#  'hous',
#  'wife',
#  'ruth',
#  'tell',
#  'properti',
#  'inquir',
#  'sell',
#  'month',
#  'sign',
#  'wong',
#  'recal',
#  'tyrus',
#  'japanes',
#  'attack',
#  'pearl',
#  'harbor',
#  'decemb',
#  'wong',
#  'like',
#  'take',
#  'wear',
#  'lapel',
#  'button',
#  'proclaim',
#  'heritag',
#  'lest',
#  'angri',
#  'american',
#  'beat',
#  'street',
#  'perman',
#  'dispers',
#  'fledgl',
#  'orient',
#  'artist',
#  'group',
#  'wong',
#  'friend',
#  'okubo',
#  'send',
#  'ten',
#  'thousand',
#  'intern',
#  'camp',
#  'world',
#  'hadn',
#  'happen',
#  'think',
#  'artist',
#  'artist',
#  'today',
#  'say',
#  'littl',
#  'movement',
#  'bare',
#  'start',
#  'split',
#  'apart',
#  'wong',
#  'unit',
#  'state',
#  'citizen',
#  'design',
#  'christma',
#  'card',
#  'hallmark',
#  'paint',
#  'eleg',
#  'design',
#  'dinnerwar',
#  'seek',
#  'collector',
#  'longtim',
#  'resid',
#  'sunland',
#  'calif',
#  'retir',
#  'renown',
#  'kitemak',
#  'design',
#  'build',
#  'hand',
#  'color',
#  'astonish',
#  'airworthi',
#  'creation',
#  'butterfli',
#  'swallow',
#  'flock',
#  'owl',
#  'centiped',
#  'feet',
#  'long',
#  'streak',
#  'southern',
#  'california',
#  'like',
#  'paint',
#  'blue',
#  'canva',
#  'year',
#  'ruth',
#  'wong',
#  'life',
#  'dementia',
#  'wong',
#  'forsak',
#  'work',
#  'care',
#  'death',
#  'slowli',
#  'begin',
#  'make',
#  'formal',
#  'recognit',
#  'influenc',
#  'bambi',
#  'wong',
#  'name',
#  'disney',
#  'legend',
#  'honor',
#  'previous',
#  'recipi',
#  'includ',
#  'fred',
#  'macmurray',
#  'juli',
#  'andrew',
#  'annett',
#  'funicello',
#  'bestow',
#  ...]

# %%
for index, score in sorted(lda_model[bow_corpus[2]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model.print_topic(index, 10)))
# Out:
# Score: 0.7446389198303223
# Topic: 0.005*"go" + 0.005*"know" + 0.005*"work" + 0.004*"think" + 0.004*"come" + 0.004*"tell" + 0.004*"game" + 0.003*"want" + 0.003*"play" + 0.003*"world"
#
# Score: 0.16126777231693268
# Topic: 0.006*"compani" + 0.006*"china" + 0.005*"appl" + 0.005*"state" + 0.004*"trump" + 0.004*"come" + 0.003*"work" + 0.003*"countri" + 0.003*"go" + 0.003*"tell"
#
# Score: 0.06846994161605835
# Topic: 0.007*"student" + 0.006*"school" + 0.005*"attack" + 0.005*"north" + 0.004*"countri" + 0.004*"state" + 0.004*"nation" + 0.004*"korea" + 0.003*"tell" + 0.003*"polic"
#
# Score: 0.024962862953543663
# Topic: 0.010*"state" + 0.007*"presid" + 0.006*"countri" + 0.006*"unit" + 0.006*"attack" + 0.005*"isi" + 0.005*"govern" + 0.005*"obama" + 0.005*"immigr" + 0.005*"group"

# %% [markdown]
# Our test document has the highest probability to be part of the topic on the top.

# %% [markdown]
# ### Performance evaluation by classifying sample document using LDA TF-IDF model

# %%
for index, score in sorted(lda_model_tfidf[bow_corpus[2]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model_tfidf.print_topic(index, 10)))
# Out:
# Score: 0.608140230178833
# Topic: 0.001*"market" + 0.001*"compani" + 0.001*"water" + 0.001*"china" + 0.001*"world" + 0.001*"health" + 0.001*"polic" + 0.001*"food" + 0.001*"citi" + 0.001*"work"
#
# Score: 0.37228599190711975
# Topic: 0.002*"clinton" + 0.002*"trump" + 0.002*"insur" + 0.002*"obamacar" + 0.001*"email" + 0.001*"film" + 0.001*"court" + 0.001*"health" + 0.001*"depart" + 0.001*"attorney"
#
# Score: 0.017662575468420982
# Topic: 0.005*"trump" + 0.004*"clinton" + 0.003*"poll" + 0.002*"vote" + 0.002*"voter" + 0.002*"percent" + 0.002*"republican" + 0.002*"black" + 0.002*"hillari" + 0.002*"democrat"

# %% [markdown]
# Our test document has the highest probability to be part of the topic on the top.

# %% [markdown]
# ### Testing model on unseen document

# %%
unseen_document = 'How a Pentagon deal became an identity crisis for Google'
bow_vector = dictionary.doc2bow(preprocess(unseen_document))

for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    print("Score: {}\t Topic: {}".format(score, lda_model.print_topic(index, 5)))
# Out:
# Score: 0.7234691977500916	 Topic: 0.014*"state" + 0.012*"court" + 0.005*"trump" + 0.005*"justic" + 0.005*"govern"
# Score: 0.14316491782665253	 Topic: 0.006*"compani" + 0.006*"china" + 0.005*"appl" + 0.005*"state" + 0.004*"trump"
# Score: 0.01667333021759987	 Topic: 0.016*"trump" + 0.009*"republican" + 0.008*"presid" + 0.007*"senat" + 0.005*"compani"
# Score: 0.016672896221280098	 Topic: 0.010*"state" + 0.007*"presid" + 0.006*"countri" + 0.006*"unit" + 0.006*"attack"
# Score: 0.0166714359074831	 Topic: 0.032*"trump" + 0.009*"clinton" + 0.006*"republican" + 0.005*"state" + 0.005*"donald"
# Score: 0.016671301797032356	 Topic: 0.007*"student" + 0.006*"school" + 0.005*"attack" + 0.005*"north" + 0.004*"countri"
# Score: 0.016670258715748787	 Topic: 0.007*"health" + 0.004*"work" + 0.004*"report" + 0.004*"drug" + 0.004*"tell"
# Score: 0.016669033095240593	 Topic: 0.005*"go" + 0.005*"know" + 0.005*"work" + 0.004*"think" + 0.004*"come"
# Score: 0.0166690181940794	 Topic: 0.015*"polic" + 0.010*"offic" + 0.008*"report" + 0.006*"state" + 0.006*"shoot"
# Score: 0.016668597236275673	 Topic: 0.027*"trump" + 0.013*"clinton" + 0.011*"presid" + 0.008*"campaign" + 0.007*"democrat"
